# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing
import seaborn as sns
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
sns.set()
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("Zoo.csv")

# %%
df1 = df.copy()

# %%
df1.head()
# Out:
#   animal name  hair  feathers  eggs  milk  airborne  aquatic  predator  \
# 0    aardvark     1         0     0     1         0        0         1
# 1    antelope     1         0     0     1         0        0         0
# 2        bass     0         0     1     0         0        1         1
# 3        bear     1         0     0     1         0        0         1
# 4        boar     1         0     0     1         0        0         1
#
#    toothed  backbone  breathes  venomous  fins  legs  tail  domestic  catsize  \
# 0        1         1         1         0     0     4     0         0        1
# 1        1         1         1         0     0     4     1         0        1
# 2        1         1         0         0     1     0     1         0        0
# 3        1         1         1         0     0     4     0         0        1
# 4        1         1         1         0     0     4     1         0        1
#
#    type
# 0     1
# 1     1
# 2     4
# 3     1
# 4     1

# %%
df1.describe()
# Out:
#              hair    feathers        eggs        milk    airborne     aquatic  \
# count  101.000000  101.000000  101.000000  101.000000  101.000000  101.000000
# mean     0.425743    0.198020    0.584158    0.405941    0.237624    0.356436
# std      0.496921    0.400495    0.495325    0.493522    0.427750    0.481335
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      0.000000    0.000000    1.000000    0.000000    0.000000    0.000000
# 75%      1.000000    0.000000    1.000000    1.000000    0.000000    1.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#          predator     toothed    backbone    breathes    venomous        fins  \
# count  101.000000  101.000000  101.000000  101.000000  101.000000  101.000000
# mean     0.554455    0.603960    0.821782    0.792079    0.079208    0.168317
# std      0.499505    0.491512    0.384605    0.407844    0.271410    0.376013
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    1.000000    1.000000    0.000000    0.000000
# 50%      1.000000    1.000000    1.000000    1.000000    0.000000    0.000000
# 75%      1.000000    1.000000    1.000000    1.000000    0.000000    0.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#              legs        tail    domestic     catsize        type
# count  101.000000  101.000000  101.000000  101.000000  101.000000
# mean     2.841584    0.742574    0.128713    0.435644    2.831683
# std      2.033385    0.439397    0.336552    0.498314    2.102709
# min      0.000000    0.000000    0.000000    0.000000    1.000000
# 25%      2.000000    0.000000    0.000000    0.000000    1.000000
# 50%      4.000000    1.000000    0.000000    0.000000    2.000000
# 75%      4.000000    1.000000    0.000000    1.000000    4.000000
# max      8.000000    1.000000    1.000000    1.000000    7.000000

# %%
sns.catplot(x='type', data=df1, kind="count", height=5, aspect=2)

# %%
df1.plot(kind='density', subplots=True, layout=(4,5), figsize=(13,20), sharex=False, sharey=False)
plt.show()

# %%
df1.plot(kind='box', subplots=True, layout=(4,5), figsize=(13,20), sharex=False, sharey=False)
plt.show()

# %%
cor = df1.corr(method='pearson')

# %%
cor.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_6ad6d_row0_col0, #T_6ad6d_row1_col1, #T_6ad6d_row2_col2, #T_6ad6d_row3_col3, #T_6ad6d_row4_col4, #T_6ad6d_row5_col5, #T_6ad6d_row6_col6, #T_6ad6d_row7_col7, #T_6ad6d_row8_col8, #T_6ad6d_row9_col9, #T_6ad6d_row10_col10, #T_6ad6d_row11_col11, #T_6ad6d_row12_col12, #T_6ad6d_row13_col13, #T_6ad6d_row14_col14, #T_6ad6d_row15_col15, #T_6ad6d_row16_col16 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_6ad6d_row0_col1, #T_6ad6d_row0_col10 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_6ad6d_row0_col2, #T_6ad6d_row5_col14 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_6ad6d_row0_col3 {
#   background-color: #cb3e38;
#   color: #f1f1f1;
# }
# #T_6ad6d_row0_col4, #T_6ad6d_row1_col12 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_6ad6d_row0_col5, #T_6ad6d_row9_col10, #T_6ad6d_row16_col14 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_6ad6d_row0_col6, #T_6ad6d_row2_col14 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_6ad6d_row0_col7 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_6ad6d_row0_col8, #T_6ad6d_row8_col0 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_6ad6d_row0_col9 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_6ad6d_row0_col11 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_6ad6d_row0_col12 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_6ad6d_row0_col13 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_6ad6d_row0_col14, #T_6ad6d_row4_col8 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_6ad6d_row0_col15 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_6ad6d_row0_col16, #T_6ad6d_row7_col10 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_6ad6d_row1_col0, #T_6ad6d_row3_col6 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_6ad6d_row1_col2, #T_6ad6d_row9_col3, #T_6ad6d_row15_col0 {
#   background-color: #f7ac8e;
#   color: #000000;
# }
# #T_6ad6d_row1_col3, #T_6ad6d_row12_col7 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_6ad6d_row1_col4 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# #T_6ad6d_row1_col5, #T_6ad6d_row10_col7, #T_6ad6d_row14_col16 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_6ad6d_row1_col6 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_6ad6d_row1_col7 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_6ad6d_row1_col8, #T_6ad6d_row13_col7 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_6ad6d_row1_col9 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_6ad6d_row1_col10 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_6ad6d_row1_col11, #T_6ad6d_row2_col6 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_6ad6d_row1_col13, #T_6ad6d_row7_col15, #T_6ad6d_row9_col8, #T_6ad6d_row11_col2, #T_6ad6d_row11_col8, #T_6ad6d_row14_col3 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_6ad6d_row1_col14, #T_6ad6d_row16_col1 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_6ad6d_row1_col15, #T_6ad6d_row2_col13, #T_6ad6d_row12_col1, #T_6ad6d_row13_col6, #T_6ad6d_row14_col5, #T_6ad6d_row15_col14 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_6ad6d_row1_col16, #T_6ad6d_row5_col1, #T_6ad6d_row15_col6 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_6ad6d_row2_col0, #T_6ad6d_row2_col3, #T_6ad6d_row2_col7, #T_6ad6d_row3_col2, #T_6ad6d_row3_col10, #T_6ad6d_row5_col9, #T_6ad6d_row6_col14, #T_6ad6d_row7_col1, #T_6ad6d_row7_col4, #T_6ad6d_row8_col10, #T_6ad6d_row8_col16, #T_6ad6d_row9_col5, #T_6ad6d_row9_col11, #T_6ad6d_row11_col12, #T_6ad6d_row14_col6, #T_6ad6d_row16_col8, #T_6ad6d_row16_col13, #T_6ad6d_row16_col15 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_6ad6d_row2_col1 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_6ad6d_row2_col4, #T_6ad6d_row7_col11, #T_6ad6d_row9_col12 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_6ad6d_row2_col5, #T_6ad6d_row6_col5 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_6ad6d_row2_col8, #T_6ad6d_row5_col10, #T_6ad6d_row5_col15 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_6ad6d_row2_col9, #T_6ad6d_row5_col12, #T_6ad6d_row7_col2, #T_6ad6d_row15_col4 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_6ad6d_row2_col10, #T_6ad6d_row8_col6 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_6ad6d_row2_col11, #T_6ad6d_row6_col8 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_6ad6d_row2_col12 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_6ad6d_row2_col15, #T_6ad6d_row12_col11 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_6ad6d_row2_col16 {
#   background-color: #eb7d62;
#   color: #f1f1f1;
# }
# #T_6ad6d_row3_col0 {
#   background-color: #cc403a;
#   color: #f1f1f1;
# }
# #T_6ad6d_row3_col1 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_6ad6d_row3_col4 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_6ad6d_row3_col5, #T_6ad6d_row11_col14 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_6ad6d_row3_col7 {
#   background-color: #f18f71;
#   color: #f1f1f1;
# }
# #T_6ad6d_row3_col8 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# #T_6ad6d_row3_col9, #T_6ad6d_row15_col8 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_6ad6d_row3_col11, #T_6ad6d_row4_col5, #T_6ad6d_row4_col14, #T_6ad6d_row16_col6 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_6ad6d_row3_col12, #T_6ad6d_row8_col11, #T_6ad6d_row13_col11, #T_6ad6d_row14_col8 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_6ad6d_row3_col13, #T_6ad6d_row8_col9 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_6ad6d_row3_col14, #T_6ad6d_row10_col11 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_6ad6d_row3_col15, #T_6ad6d_row7_col0 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_6ad6d_row3_col16 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_6ad6d_row4_col0 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_6ad6d_row4_col1 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_6ad6d_row4_col2, #T_6ad6d_row5_col2 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_6ad6d_row4_col3, #T_6ad6d_row11_col0, #T_6ad6d_row15_col1 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_6ad6d_row4_col6 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_6ad6d_row4_col7 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_6ad6d_row4_col9, #T_6ad6d_row14_col0 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_6ad6d_row4_col10 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_6ad6d_row4_col11 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_6ad6d_row4_col12, #T_6ad6d_row8_col5, #T_6ad6d_row11_col3, #T_6ad6d_row14_col2 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_6ad6d_row4_col13, #T_6ad6d_row10_col0, #T_6ad6d_row10_col12 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_6ad6d_row4_col15, #T_6ad6d_row16_col3 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_6ad6d_row4_col16, #T_6ad6d_row5_col8, #T_6ad6d_row14_col9 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_6ad6d_row5_col0, #T_6ad6d_row6_col4 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_6ad6d_row5_col3 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_6ad6d_row5_col4 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_6ad6d_row5_col6, #T_6ad6d_row8_col1, #T_6ad6d_row12_col16 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_6ad6d_row5_col7, #T_6ad6d_row14_col12 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_6ad6d_row5_col11 {
#   background-color: #f39778;
#   color: #000000;
# }
# #T_6ad6d_row5_col13, #T_6ad6d_row6_col0, #T_6ad6d_row11_col15 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_6ad6d_row5_col16, #T_6ad6d_row10_col16 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_6ad6d_row6_col1, #T_6ad6d_row6_col12, #T_6ad6d_row8_col14, #T_6ad6d_row10_col9 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_6ad6d_row6_col2 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_6ad6d_row6_col3, #T_6ad6d_row6_col7 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_6ad6d_row6_col9 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_6ad6d_row6_col10, #T_6ad6d_row7_col14, #T_6ad6d_row10_col1, #T_6ad6d_row12_col14 {
#   bac

# %% [markdown]
# ### Finding optimal number of K

# %%
X = df1.iloc[:,1:17].values
y = df1.iloc[:,17].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1, stratify=y)

# %%
X_train = np.ascontiguousarray(X_train)
y_train = np.ascontiguousarray(y_train)
X_test = np.ascontiguousarray(X_test)
y_test = np.ascontiguousarray(y_test)

# %%
k_values = np.arange(1, 25)
train_accuracy = []
test_accuracy = []

# %%
for k in k_values:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)
    train_accuracy.append(knn.score(X_train, y_train))
    test_accuracy.append(knn.score(X_test, y_test))

# %%
plt.figure(figsize=[13,8])
plt.plot(k_values, test_accuracy, label = 'Testing Accuracy')
plt.plot(k_values, train_accuracy, label = 'Training Accuracy')
plt.legend()
plt.title('-value VS Accuracy')
plt.xlabel('Number of Neighbors')
plt.ylabel('Accuracy')
plt.xticks(k_values)
plt.show()

# %% [markdown]
# ### As shown in  the graph, with K=5 we can achive accurary of 90%.

# %% [markdown]
# ### Applying the algorithm

# %%
knn = KNeighborsClassifier(n_neighbors=5)

# %%
knn.fit(X_train, y_train)
y_pred_KNeighborsClassifier = knn.predict(X_test)

# %%
scores = []
cv_scores = []

# %%
score = accuracy_score(y_pred_KNeighborsClassifier,y_test)
scores.append(score)

# %%
score_knn=cross_val_score(knn, X,y, cv=10)

# %%
score_knn.mean()
# Out:
# 0.8809090909090909

# %%
score_knn.std()*2
# Out:
# 0.12072782037115655

# %%
cv_score = score_knn.mean()

# %%
cv_scores.append(cv_score)

# %%
cv_scores
# Out:
# [0.8809090909090909]

# %% [markdown]
# ### Support Vector Machine Accuracy: 0.90 (+/- 0.14)
