# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing
import seaborn as sns
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
sns.set()
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("glass.csv")

# %%
df1 = df.copy()

# %%
df1.loc[df['Type'] == 1, 'Type'] = 'building_windows_float_processed'
df1.loc[df['Type'] == 2, 'Type'] = 'building_windows_non_float_processed' 
df1.loc[df['Type'] == 3, 'Type'] = 'vehicle_windows_float_processed' 
df1.loc[df['Type'] == 4, 'Type'] = 'vehicle_windows_non_float_processed' 
df1.loc[df['Type'] == 5, 'Type'] = 'containers' 
df1.loc[df['Type'] == 6, 'Type'] = 'tableware' 
df1.loc[df['Type'] == 7, 'Type'] = 'headlamps'

# %%
df1.head()
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  \
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0
# 2  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0
# 3  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0
# 4  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0
#
#                                Type
# 0  building_windows_float_processed
# 1  building_windows_float_processed
# 2  building_windows_float_processed
# 3  building_windows_float_processed
# 4  building_windows_float_processed

# %%
df1.describe()
# Out:
#                RI          Na          Mg          Al          Si           K  \
# count  214.000000  214.000000  214.000000  214.000000  214.000000  214.000000
# mean     1.518365   13.407850    2.684533    1.444907   72.650935    0.497056
# std      0.003037    0.816604    1.442408    0.499270    0.774546    0.652192
# min      1.511150   10.730000    0.000000    0.290000   69.810000    0.000000
# 25%      1.516522   12.907500    2.115000    1.190000   72.280000    0.122500
# 50%      1.517680   13.300000    3.480000    1.360000   72.790000    0.555000
# 75%      1.519157   13.825000    3.600000    1.630000   73.087500    0.610000
# max      1.533930   17.380000    4.490000    3.500000   75.410000    6.210000
#
#                Ca          Ba          Fe
# count  214.000000  214.000000  214.000000
# mean     8.956963    0.175047    0.057009
# std      1.423153    0.497219    0.097439
# min      5.430000    0.000000    0.000000
# 25%      8.240000    0.000000    0.000000
# 50%      8.600000    0.000000    0.000000
# 75%      9.172500    0.000000    0.100000
# max     16.190000    3.150000    0.510000

# %%
sns.catplot(x='Type', data=df1, kind="count", height=5, aspect=2)

# %%
df1.plot(kind='density', subplots=True, layout=(4,5), figsize=(13,20), sharex=False, sharey=False)
plt.show()

# %%
df1.plot(kind='box', subplots=True, layout=(4,5), figsize=(13,20), sharex=False, sharey=False)
plt.show()

# %%
cor = df1.corr(method='pearson')

# %%
cor.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_7c910_row0_col0, #T_7c910_row1_col1, #T_7c910_row2_col2, #T_7c910_row3_col3, #T_7c910_row4_col4, #T_7c910_row5_col5, #T_7c910_row6_col6, #T_7c910_row7_col7, #T_7c910_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_7c910_row0_col1 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_7c910_row0_col2 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_7c910_row0_col3 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_7c910_row0_col4, #T_7c910_row1_col8, #T_7c910_row2_col1, #T_7c910_row2_col3, #T_7c910_row2_col6, #T_7c910_row2_col7, #T_7c910_row4_col0, #T_7c910_row6_col1, #T_7c910_row6_col5, #T_7c910_row7_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_7c910_row0_col5 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_7c910_row0_col6 {
#   background-color: #df634e;
#   color: #f1f1f1;
# }
# #T_7c910_row0_col7 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_7c910_row0_col8 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_7c910_row1_col0, #T_7c910_row7_col6 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_7c910_row1_col2, #T_7c910_row7_col8 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_7c910_row1_col3 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_7c910_row1_col4 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_7c910_row1_col5 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_7c910_row1_col6 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_7c910_row1_col7 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_7c910_row2_col0 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_7c910_row2_col4, #T_7c910_row2_col5 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_7c910_row2_col8, #T_7c910_row4_col7 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_7c910_row3_col0, #T_7c910_row5_col6 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_7c910_row3_col1 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_7c910_row3_col2, #T_7c910_row5_col1 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_7c910_row3_col4, #T_7c910_row7_col0 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_7c910_row3_col5 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_7c910_row3_col6 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_7c910_row3_col7, #T_7c910_row7_col3 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_7c910_row3_col8 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_7c910_row4_col1, #T_7c910_row4_col6, #T_7c910_row5_col0 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_7c910_row4_col2, #T_7c910_row6_col4 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_7c910_row4_col3 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_7c910_row4_col5 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_7c910_row4_col8 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_7c910_row5_col2 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_7c910_row5_col3 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_7c910_row5_col4 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_7c910_row5_col7 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_7c910_row5_col8 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_7c910_row6_col0 {
#   background-color: #dd5f4b;
#   color: #f1f1f1;
# }
# #T_7c910_row6_col2 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_7c910_row6_col3 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_7c910_row6_col7 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_7c910_row6_col8 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_7c910_row7_col1 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_7c910_row7_col4 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_7c910_row7_col5 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_7c910_row8_col0 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_7c910_row8_col1 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_7c910_row8_col2 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_7c910_row8_col3 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_7c910_row8_col4, #T_7c910_row8_col7 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_7c910_row8_col5 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_7c910_row8_col6 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# </style>
# <table id="T_7c910">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7c910_level0_col0" class="col_heading level0 col0" >RI</th>
#       <th id="T_7c910_level0_col1" class="col_heading level0 col1" >Na</th>
#       <th id="T_7c910_level0_col2" class="col_heading level0 col2" >Mg</th>
#       <th id="T_7c910_level0_col3" class="col_heading level0 col3" >Al</th>
#       <th id="T_7c910_level0_col4" class="col_heading level0 col4" >Si</th>
#       <th id="T_7c910_level0_col5" class="col_heading level0 col5" >K</th>
#       <th id="T_7c910_level0_col6" class="col_heading level0 col6" >Ca</th>
#       <th id="T_7c910_level0_col7" class="col_heading level0 col7" >Ba</th>
#       <th id="T_7c910_level0_col8" class="col_heading level0 col8" >Fe</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7c910_level0_row0" class="row_heading level0 row0" >RI</th>
#       <td id="T_7c910_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_7c910_row0_col1" class="data row0 col1" >-0.191885</td>
#       <td id="T_7c910_row0_col2" class="data row0 col2" >-0.122274</td>
#       <td id="T_7c910_row0_col3" class="data row0 col3" >-0.407326</td>
#       <td id="T_7c910_row0_col4" class="data row0 col4" >-0.542052</td>
#       <td id="T_7c910_row0_col5" class="data row0 col5" >-0.289833</td>
#       <td id="T_7c910_row0_col6" class="data row0 col6" >0.810403</td>
#       <td id="T_7c910_row0_col7" class="data row0 col7" >-0.000386</td>
#       <td id="T_7c910_row0_col8" class="data row0 col8" >0.143010</td>
#     </tr>
#     <tr>
#       <th id="T_7c910_level0_row1" class="row_heading level0 row1" >Na</th>
#       <td id="T_7c910_row1_col0" class="data row1 col0" >-0.191885</td>
#       <td id="T_7c910_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_7c910_row1_col2" class="data row1 col2" >-0.273732</td>
#       <td id="T_7c910_row1_col3" class="data row1 col3" >0.156794</td>
#       <td id="T_7c910_row1_col4" class="data row1 col4" >-0.069809</td>
#       <td id="T_7c910_row1_col5" class="data row1 col5" >-0.266087</td>
#       <td id="T_7c910_row1_col6" class="data row1 col6" >-0.275442</td>
#       <td id="T_7c910_row1_col7" class="data row1 col7" >0.326603</td>
#       <td id="T_7c910_row1_col8" class="data row1 col8" >-0.241346</td>
#     </tr>
#     <tr>
#       <th id="T_7c910_level0_row2" class="row_heading level0 row2" >Mg</th>
#       <td id="T_7c910_row2_col0" class="data row2 col0" >-0.122274</td>
#       <td id="T_7c910_row2_col1" class="data row2 col1" >-0.273732</td>
#       <td id="T_7c910_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_7c910_row2_col3" class="data row2 col3" >-0.481799</td>
#       <td id="T_7c910_row2_col4" class="data row2 col4" >-0.165927</td>
#       <td id="T_7c910_row2_col5" class="data row2 col5" >0.005396</td>
#       <td id="T_7c910_row2_col6" class="data row2 col6" >-0.443750</td>
#       <td id="T_7c910_row2_col7" class="data row2 col7" >-0.492262</td>
#       <td id="T_7c910_row2_col8" class="data row2 col8" >0.083060</td>
#     </tr>
#     <tr>
#       <th id="T_7c910_level0_row3" class="row_heading level0 row3" >Al</th>
#       <td id="T_7c910_row3_col0" class="data row3 col0" >-0.407326</td>
#       <td id="T_7c910_row3_col1" class="data row3 col1" >0.156794</td>
#       <td id="T_7c910_row3_col2" class="data row3 col2" >-0.481799</td>
#       <td id="T_7c910_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_7c910_row3_col4" class="data row3 col4" >-0.005524</td>
#       <td id="T_7c910_row3_col5" class="data row3 col5" >0.325958</td>
#       <td id="T_7c910_row3_col6" class="data row3 col6" >-0.259592</td>
#       <td id="T_7c910_row3_col7" class="data row3 col7" >0.479404</td>
#       <td id="T_7c910_row3_col8" class="data row3 col8" >-0.074402</td>

# %% [markdown]
# ### Finding optimal number of K

# %%
X = np.array(df1.iloc[:,3:5])
y = np.array(df1['Type'])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1, stratify=y)

# %%
k_values = np.arange(1,25)
train_accuracy = []
test_accuracy = []

# %%
for i, k in enumerate(k_values):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train,y_train)
    train_accuracy.append(knn.score(X_train, y_train))
    test_accuracy.append(knn.score(X_test, y_test))

# %%
plt.figure(figsize=[13,8])
plt.plot(k_values, test_accuracy, label = 'Testing Accuracy')
plt.plot(k_values, train_accuracy, label = 'Training Accuracy')
plt.legend()
plt.title('-value VS Accuracy')
plt.xlabel('Number of Neighbors')
plt.ylabel('Accuracy')
plt.xticks(k_values)
plt.show()

# %% [markdown]
# ### Applying the algorithm

# %%
knn = KNeighborsClassifier(n_neighbors=4)

# %%
knn.fit(X_train, y_train)
y_pred_KNeighborsClassifier = knn.predict(X_test)

# %%
scores = []
cv_scores = []

# %%
score = accuracy_score(y_pred_KNeighborsClassifier,y_test)
scores.append(score)

# %%
score_knn=cross_val_score(knn, X,y, cv=10)

# %%
score_knn.mean()
# Out:
# 0.6127705627705629

# %%
score_knn.std()*2
# Out:
# 0.23547117559816877

# %%
cv_score = score_knn.mean()

# %%
cv_scores.append(cv_score)

# %%
cv_scores
# Out:
# [0.6127705627705629]

# %% [markdown]
# ### Support Vector Machine Accuracy: 0.60 (+/- 0.21)
